# %% [markdown]
# # Initialization

# %%
# %pylab inline
import backend  # holds classes and functions implemented to date
import os       # used to get the current working directory
reload(backend)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'backend' from 'backend.pyc'>

# %% [markdown]
# In current project we have split the functions into separate classes by their task.

# %% [markdown]
# DataManager takes care of all the data importing.

# %%
manager = backend.DataManager()

# %% [markdown]
# DataAnalyzer takes care of functions that could be used during analysis.

# %%
analyzer = backend.DataAnalyzer()

# %% [markdown]
# # Reading the data

# %% [markdown]
# First we ask DataMananager to import of all the csv gimlet files into the in-memory SQLite3 database for our further use. (As a matter of fact, it is also possible to use any other SQL complient database for that purpose). It would iterate over all the files in the specified folder and load any '.csv' files that is finds.

# %%
data = manager.import_data(os.path.join(os.getcwd(), 'dataset')) 
con  = manager.save_data_to_db(data)
# Out:
# Reading input data files from /home/vladimir/Downloads/lib_project/dataset
# Found GimletDownload2012_11.csv ...
# 14737  records imported
# Found GimletDownload2012_07.csv ... 2595  records imported
# Found GimletDownload2012_12.csv ...
# 9696  records imported
# Found GimletDownload2013_02.csv ...
# 9599  records imported
# Found GimletDownload2012_08.csv ... 3672  records imported
# Found GimletDownload2012_10.csv ...
# 13595  records imported
# Found GimletDownload2012_09.csv ... 3817  records imported
# Found GimletDownload2013_01.csv ...
# 5820  records imported
#
# Creating database layout...
# Table created.
#
# Inserting data into database...
# Done.

# %% [markdown]
# ### Lets see how many total entries we have imported

# %%
q = backend.QueryBuilder()
q.limit = 0
q.show = False
rows = q.execute(con)
print 'Total amount of questions imported', len(rows)
# Out:
# Columns:  ['*']
# Conditions:  []
# Limit: 0
# Total amount of questions imported 63523

# %% [markdown]
# # Custom Queries and Data subsetting

# %% [markdown]
# Since the initial loaded data contains a lot of colums, you may want to specisy a subset of data you are interested in. This would greatly facilitate analysis and improve the software performance. Furthermore, you may or may not want to see some data displayed on the screen. Custom queries are build in a way that simplifies data navigation, they provide all the necessary functionality for analyzing the available dataset.

# %% [markdown]
# ### Getting the information about available colums

# %% [markdown]
# Lets have a look at columns that we have found in our input dataset. More in-depth analysis would be covered in the next chapter. The information here is just to show what data we are operating with.

# %%
manager.get_python_columns(data)
# Out:
# ['filename',
#  'Question_Number',
#  'Initials',
#  'Email',
#  'Location',
#  'Duration',
#  'Format',
#  'Questioner',
#  'Question_Type',
#  'Difficulty',
#  'Asked_At',
#  'Question_Date',
#  'Question_Time',
#  'Question_Half_Hour',
#  'Question_Weekday',
#  'Added_At_GMT',
#  'Tags',
#  'Site',
#  'Account',
#  'Question',
#  'Answer']

# %% [markdown]
# ### Creating a custom query and using subset functionality

# %% [markdown]
# This is where custom queries and data subsets can help. Lets say we are only interested in "What are the questions that don't have an answer inside the database?". In order to do that we create a new custom query:

# %%
q = backend.QueryBuilder()

# %% [markdown]
# Currently the query is empty and doesn't contain any information. Lets specify the columns that we are interested in and conditions. The only condition we have is to make sure that the answer is 'empty' or 'null' in programming terms. We may set a limit to make sure we don't get way too many results. Default is 10, but you may experiment with the amount that you are most comfortable with.

# %%
q.set_columns( ['Question', 'Email', 'Answer'] )
q.set_condition('Answer', 'null')
q.set_condition('AND Question NOT', 'null')
q.limit = 25

# %% [markdown]
# The only thing that is left is to execute the query and check its result:

# %%
q.execute(con)
# Out:
# Columns:  ['Question', 'Email', 'Answer']
# Conditions:  [('Answer', 'null'), ('AND Question NOT', 'null')]
# Limit: 25
# [('magazines', 'accessgimlet@gmail.com', 'null'),
#  ('restroom', 'accessgimlet@gmail.com', 'null'),
#  ('looking for a book about Lincoln and wanted to request My Beloved World by Sotomayor',
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ('Where buy print card', 'kinglibraryreference@gmail.com', 'null'),
#  ('newspaper  san jose mercury news ', 'accessgimlet@gmail.com', 'null'),
#  ('How send to print', 'kinglibraryreference@gmail.com', 'null'),
#  ('government publications', 'accessgimlet@gmail.com', 'null'),
#  ('book ', 'accessgimlet@gmail.com', 'null'),
#  ('LL 03 ', 'accessgimlet@gmail.com', 'null'),
#  ('1980s copy of Good Housekeeping magazine',
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ('study room ', 'accessgimlet@gmail.com', 'null'),
#  ('How sign on the computer', 'kinglibraryreference@gmail.com', 'null'),
#  ('study room ', 'accessgimlet@gmail.com', 'null'),
#  ('computer assistance ', 'accessgimlet@gmail.com', 'null'),
#  ('Helping attach a file to an online resume',
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ('wanted to put a hold on a book about smoking/search for one ',
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ('Nubs: the true story of a dog', 'angie.miraflor@sjlibrary.org', 'null'),
#  ('advisory that ppl will be coming downstairs to film (from 3rd floor)',
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ("Women's Indian captivity narratives",
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ("Title search: Grave matters : excavating California's buried past ",
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ('List of used car dealers in San Jose',
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ('Rm 213', 'kinglibraryreference@gmail.com', 'null'),
#  ('Biography', 'angie.miraflor@sjlibrary.org', 'null'),
#  ('need phone number for Daily Donuts on cunnyvale/saratoga',
#   'kinglibraryreference@gmail.com',
#   'null'),
#  ('picture books where', 'angie.miraflor@sjlibrary.org', 'null')]

# %% [markdown]
# As a matter of fact the beauty of this approach lies withis the notion of improving your search. You can easily add new conditions to the existing query to narrow results even further. Lets assume that we are only interested in questions that were asked over the phone. Notice that each time you execute a query it prints the values that were set during that particular execution.

# %%
q.set_columns( ['Question', 'Answer', 'Format'] )
q.set_condition('AND Format', 'Phone')
q.execute(con)
# Out:
# Columns:  ['Question', 'Answer', 'Format']
# Conditions:  [('Answer', 'null'), ('AND Question NOT', 'null'), ('AND Format', 'Phone')]
# Limit: 25
# [('looking for a book about Lincoln and wanted to request My Beloved World by Sotomayor',
#   'null',
#   'Phone (Remote)'),
#  ('1980s copy of Good Housekeeping magazine', 'null', 'Phone (Remote)'),
#  ("Women's Indian captivity narratives", 'null', 'Phone (Remote)'),
#  ('need phone number for Daily Donuts on cunnyvale/saratoga',
#   'null',
#   'Phone (Remote)'),
#  ('1800 for Amtrak', 'null', 'Phone (Remote)'),
#  ('Definitions of Aristocracy, Plutocracy and Kleptocracy',
#   'null',
#   'Phone (Remote)'),
#  ('What type of services do you have for ebook support?',
#   'null',
#   'Phone (Remote)'),
#  ('Person started to ask a question about a phone number lookup but decided to call back.',
#   'null',
#   'Phone (Remote)'),
#  ('I have 2 textbooks for you to lookup.', 'null', 'Phone (Remote)'),
#  ('Patron needs information on coursework from previous SJSU catalogs copied and sent to her',
#   'null',
#   'Phone (Remote)'),
#  ('understanding and using english grammar', 'null', 'Phone (Remote)'),
#  ('Fundamentals of English grammar ', 'null', 'Phone (Remote)'),
#  ('Copyediting & proofreading for dummies ', 'null', 'Phone (Remote)'),
#  ('Powerful proofreading skills', 'null', 'Phone (Remote)'),
#  ('Longman dictionary of American English ', 'null', 'Phone (Remote)'),
#  ('step by step word 2010  ', 'null', 'Phone (Remote)'),
#  ('where is 2-52', 'null', 'Phone (Remote)'),
#  ('war of the sexes', 'null', 'Phone (Remote)'),
#  ('beyond human nature', 'null', 'Phone (Remote)'),
#  ('sheriff deputy', 'null', 'Phone (Remote)'),
#  ('wanted to place holds on two books', 'null', 'Phone (Remote)'),
#  ('what time is it', 'null', 'Phone (Remote)'),
#  ('when do you have Tax Help?', 'null', 'Phone (Remote)'),
#  ('stubhub phone numbers', 'null', 'Phone (Remote)'),
#  ('when we close today?', 'null', 'Phone (Remote)')]

# %% [markdown]
# What a great example of how small amount of data can still be overwhelming. This is a perfect place to show the 'display' function. It allows you to specify which particular information you are interested in, even though you may construct a very massive and complicated query. We are only interested in the questions themselves right now, so lets specify 'Question' as the only display field.

# %%
q.display(['Question'])
# Out:
# looking for a book about Lincoln and wanted to request My Beloved World by Sotomayor
# 1980s copy of Good Housekeeping magazine
# Women's Indian captivity narratives
# need phone number for Daily Donuts on cunnyvale/saratoga
# 1800 for Amtrak
# Definitions of Aristocracy, Plutocracy and Kleptocracy
# What type of services do you have for ebook support?
# Person started to ask a question about a phone number lookup but decided to call back.
# I have 2 textbooks for you to lookup.
# Patron needs information on coursework from previous SJSU catalogs copied and sent to her
# understanding and using english grammar
# Fundamentals of English grammar
# Copyediting & proofreading for dummies
# Powerful proofreading skills
# Longman dictionary of American English
# step by step word 2010
# where is 2-52
# war of the sexes
# beyond human nature
# sheriff deputy
# wanted to place holds on two books
# what time is it
# when do you have Tax Help?
# stubhub phone numbers
# when we close today?

# %% [markdown]
# After a quick look over the returned dataset one may notice that people often ask if the book is currently available. That seems like a reasonable question to me, but what if we want to know what are the questions that are not about books, but about magazines and periodicals? In order to do that we need to add more conditions to our query.

# %%
q.set_columns( ['Answer', 'Email', 'Question', 'Format'] )
q.set_condition('AND Question NOT', 'book')
q.set_condition('AND Question', 'magazine')
q.limit = 25
q.execute(con)
q.display(['Question'])
# Out:
# Columns:  ['Answer', 'Email', 'Question', 'Format']
# Conditions:  [('Answer', 'null'), ('AND Question NOT', 'null'), ('AND Format', 'Phone'), ('AND Question NOT', 'book'), ('AND Question', 'magazine')]
# Limit: 25
# 1980s copy of Good Housekeeping magazine
# Life magazine
# Life Magazine from september 1942
# Do you carry a magazine called Gramophone?
# Hi, i am looking for an article from the JSTOR magazine. Here's the information 2005 vol:120 iss:1 pg:50
# magazines
# looking for magazine
# Science magazine 1987 Vol 236 pp. 280-285

# %% [markdown]
# # Natural Language Processing and Data analysis

# %% [markdown]
# NLTK is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning.

# %% [markdown]
# ### Word frequency distribution in a given column

# %% [markdown]
# In order to analyze the questions with help of Natural Language Processing Library we need to first
#
# get the body of all the questions that we have imported. This step basically concatenates all of the imported questions into one huge body of text for further analysis.

# %%
text = analyzer.db_get_full_text(con)   # this takes into account every question that is loaded
# Out:
# Analyzing questions text-body... Done.

# %% [markdown]
# One of the cool functions of analyzer is the ability to display the most popular words in
#
# the questions text-body or any of its subsets.

# %%
analyzer.get_most_frequest_words(text, 500)   # second parameter specifies the number of results returned
# Out:
# [('null', 28153),
#  ('books', 3247),
#  ('book', 2894),
#  ('computer', 2405),
#  ('library', 2319),
#  ('looking', 2192),
#  ('card', 2046),
#  ('find', 1616),
#  ('need', 1568),
#  ('help', 1525),
#  ('print', 1525),
#  ('patron', 1253),
#  ('get', 1186),
#  ('room', 1157),
#  ('use', 953),
#  ('check', 945),
#  ('wanted', 862),
#  ('student', 796),
#  ('number', 769),
#  ('printing', 762),
#  ('time', 748),
#  ('laptop', 657),
#  ('articles', 648),
#  ('needed', 586),
#  ('know', 569),
#  ('4', 564),
#  ('phone', 559),
#  ('information', 557),
#  ('machine', 520),
#  ('paper', 520),
#  ('hour', 513),
#  ('access', 509),
#  ('reserve', 504),
#  ('copy', 502),
#  ('study', 501),
#  ('floor', 496),
#  ('checkout', 487),
#  ('customer', 481),
#  ('question', 472),
#  ('san', 439),
#  ('sjsu', 429),
#  ('new', 427),
#  ('computers', 420),
#  ('could', 415),
#  ('email', 401),
#  ('article', 400),
#  ('research', 400),
#  ('lost', 386),
#  ('want', 385),
#  ('cant', 382),
#  ('would', 377),
#  ('search', 373),
#  ('hours', 366),
#  ('account', 364),
#  ('hold', 363),
#  ('one', 361),
#  ('pin', 361),
#  ('assistance', 354),
#  ('jose', 340),
#  ('im', 335),
#  ('open', 333),
#  ('asked', 332),
#  ('class', 322),
#  ('needs', 321),
#  ('working', 311),
#  ('scanner', 307),
#  ('journal', 306),
#  ('catalog', 302),
#  ('look', 302),
#  ('like', 297),
#  ('public', 288),
#  ('finding', 287),
#  ('info', 286),
#  ('request', 285),
#  ('usb', 285),
#  ('course', 279),
#  ('wants', 278),
#  ('microfilm', 270),
#  ('log', 269),
#  ('extension', 264),
#  ('work', 259),
#  ('found', 254),
#  ('printer', 254),
#  ('newspaper', 252),
#  ('fines', 241),
#  ('online', 241),
#  ('available', 240),
#  ('today', 240),
#  ('call', 239),
#  ('pay', 235),
#  ('add', 234),
#  ('change', 234),
#  ('see', 228),
#  ('using', 228),
#  ('dvd', 224),
#  ('link', 223),
#  ('renew', 223),
#  ('questions', 222),
#  ('childrens', 220),
#  ('money', 219),
#  ('wireless', 219),
#  ('section', 218),
#  ('document', 216),
#  ('trying', 215),
#  ('2', 213),
#  ('address', 213),
#  ('history', 213),
#  ('dont', 207),
#  ('return', 207),
#  ('borrow', 206),
#  ('title', 206),
#  ('problem', 202),
#  ('dvds', 201),
#  ('stapler', 198),
#  ('item', 197),
#  ('specific', 195),
#  ('apply', 194),
#  ('go', 192),
#  ('materials', 192),
#  ('chinese', 191),
#  ('branch', 188),
#  ('business', 186),
#  ('word', 185),
#  ('1', 183),
#  ('login', 183),
#  ('wifi', 183),
#  ('hear', 179),
#  ('collection', 178),
#  ('two', 176),
#  ('ebook', 174),
#  ('language', 174),
#  ('databases', 172),
#  ('job', 171),
#  ('drive', 169),
#  ('make', 169),
#  ('called', 168),
#  ('put', 166),
#  ('213', 164),
#  ('california', 164),
#  ('another', 161),
#  ('music', 160),
#  ('close', 159),
#  ('spanish', 159),
#  ('location', 158),
#  ('cannot', 157),
#  ('problems', 157),
#  ('reference', 157),
#  ('restroom', 156),
#  ('someone', 156),
#  ('checked', 154),
#  ('ipad', 153),
#  ('pick', 152),
#  ('please', 152),
#  ('topic', 152),
#  ('magazines', 149),
#  ('art', 148),
#  ('id', 148),
#  ('also', 147),
#  ('back', 147),
#  ('save', 146),
#  ('trouble', 146),
#  ('internet', 144),
#  ('american', 143),
#  ('resume', 143),
#  ('students', 143),
#  ('database', 142),
#  ('person', 142),
#  ('station', 141),
#  ('take', 140),
#  ('items', 138),
#  ('school', 138),
#  ('download', 136),
#  ('king', 133),
#  ('somebody', 131),
#  ('etc', 130),
#  ('fiction', 130),
#  ('health', 130),
#  ('says', 130),
#  ('science', 129),
#  ('something', 129),
#  ('wheres', 129),
#  ('issue', 128),
#  ('mercury', 128),
#  ('resources', 128),
#  ('sign', 128),
#  ('old', 127),
#  ('show', 127),
#  ('us', 127),
#  ('wont', 127),
#  ('city', 126),
#  ('english', 126),
#  ('microfiche', 125),
#  ('santa', 125),
#  ('still', 125),
#  ('social', 123),
#  ('center', 122),
#  ('news', 122),
#  ('magazine', 121),
#  ('name', 121),
#  ('tower', 121),
#  ('3', 120),
#  ('issues', 120),
#  ('website', 117),
#  ('text', 116),
#  ('file', 115),
#  ('list', 115),
#  ('tell', 115),
#  ('textbook', 115),
#  ('place', 114),
#  ('holds', 112),
#  ('shelf', 112),
#  ('give', 111),
#  ('office', 111),
#  ('program', 111),
#  ('reading', 111),
#  ('area', 110),
#  ('searching', 110),
#  ('children', 109),
#  ('journals', 109),
#  ('many', 109),
#  ('newspapers', 109),
#  ('page', 109),
#  ('parking', 109),
#  ('didnt', 108),
#  ('government', 108),
#  ('locate', 108),
#  ('seeking', 108),
#  ('home', 107),
#  ('college', 106),
#  ('librarian', 106),
#  ('ebooks', 105),
#  ('much', 105),
#  ('week', 105),
#  ('regarding', 104),
#  ('asking', 103),
#  ('reserves', 103),
#  ('reset', 103),
#  ('desk', 102),
#  ('forgot', 102),
#  ('returned', 102),
#  ('services', 102),
#  ('form', 101),
#  ('read', 101),
#  ('scan', 101),
#  ('contact', 100),
#  ('couldnt', 100),
#  ('system', 100),
#  ('getting', 98),
#  ('long', 98),
#  ('value', 98),
#  ('writing', 98),
#  ('pencil', 97),
#  ('scratch', 97),
#  ('able', 96),
#  ('pages', 96),
#  ('reservation', 96),
#  ('doesnt', 95),
#  ('meeting', 95),
#  ('sure', 95),
#  ('test', 95),
#  ('used', 95),
#  ('5', 94),
#  ('buy', 94),
#  ('copier', 94),
#  ('material', 94),
#  ('located', 93),
#  ('sources', 93),
#  ('3rd', 92),
#  ('application', 92),
#  ('came', 92),
#  ('pdf', 92),
#  ('send', 92),
#  ('state', 92),
#  ('copies', 91),
#  ('learning', 91),
#  ('numbers', 91),
#  ('tried', 91),
#  ('series', 90),
#  ('sj', 90),
#  ('sjpl', 90),
#  ('times', 90),
#  ('225', 89),
#  ('collections', 89),
#  ('juvenile', 89),
#  ('reserved', 89),
#  ('screen', 89),
#  ('2nd', 88),
#  ('clara', 88),
#  ('different', 88),
#  ('overdrive', 88),
#  ('rooms', 88),
#  ('cd', 87),
#  ('child', 87),
#  ('day', 87),
#  ('headphones', 87),
#  ('scanning', 87),
#  ('code', 86),
#  ('last', 86),
#  ('locating', 86),
#  ('people', 86),
#  ('come', 85),
#  ('mezzanine', 85),
#  ('password', 85),
#  ('refworks', 85),
#  ('tax', 85),
#  ('county', 84),
#  ('street', 84),
#  ('way', 84),
#  ('caller', 83),
#  ('esl', 83),
#  ('flash', 83),
#  ('isnt', 81),
#  ('directions', 80),
#  ('first', 80),
#  ('guide', 80),
#  ('late', 80),
#  ('lawyers', 80),
#  ('logging', 80),
#  ('pen', 80),
#  ('free', 79),
#  ('let', 79),
#  ('particular', 79),
#  ('sjmn', 79),
#  ('staff', 79),
#  ('law', 78),
#  ('author', 77),
#  ('ca', 77),
#  ('faculty', 77),
#  ('level', 77),
#  ('year', 77),
#  ('cash', 76),
#  ('full', 76),
#  ('titles', 76),
#  ('booking', 75),
#  ('classes', 75),
#  ('extend', 75),
#  ('university', 74),
#  ('world', 74),
#  ('error', 73),
#  ('may', 73),
#  ('message', 73),
#  ('service', 73),
#  ('campus', 72),
#  ('got', 72),
#  ('left', 72),
#  ('machines', 72),
#  ('review', 72),
#  ('said', 72),
#  ('cds', 71),
#  ('dictionary', 71),
#  ('floppy', 71),
#  ('kids', 71),
#  ('mezz', 71),
#  ('set', 71),
#  ('expired', 70),
#  ('food', 70),
#  ('mean', 70),
#  ('picture', 70),
#  ('sent', 70),
#  ('war', 70),
#  ('care', 69),
#  ('google', 69),
#  ('speak', 69),
#  ('without', 69),
#  ('maps', 68),
#  ('security', 68),
#  ('told', 68),
#  ('assignment', 67),
#  ('good', 67),
#  ('media', 67),
#  ('rac', 67),
#  ('219', 66),
#  ('apa', 66),
#  ('going', 66),
#  ('report', 66),
#  ('turned', 66),
#  ('movies', 65),
#  ('whats', 65),
#  ('already', 64),
#  ('connect', 64),
#  ('movie', 64),
#  ('onto', 64),
#  ('status', 64),
#  ('education', 63),
#  ('exam', 63),
#  ('fine', 63),
#  ('manual', 63),
#  ('self', 63),
#  ('several', 63),
#  ('start', 63),
#  ('water', 63),
#  ('appointment', 62),
#  ('diary', 62),
#  ('encyclopedia', 62),
#  ('learn', 62),
#  ('looked', 62),
#  ('order', 62),
#  ('professor', 62),
#  ('project', 62),
#  ('release', 62),
#  ('audio', 61),
#  ('cancel', 61),
#  ('civil', 61),
#  ('due', 61),
#  ('engineering', 61),
#  ('kindle', 61),
#  ('repair', 61),
#  ('requested', 61),
#  ('spell', 61),
#  ('talk', 61),
#  ('turn', 61),
#  ('write', 61),
#  ('wrong', 61),
#  ('biography', 60),
#  ('disk', 60),
#  ('right', 60),
#  ('tonight', 60),
#  ('bill', 59),
#  ('group', 59),
#  ('record', 59),
#  ('studies', 59),
#  ('certain', 58),
#  ('culture', 58),
#  ('map', 58),
#  ('scholarly', 58),
#  ('textbooks', 58),
#  ('tomorrow', 58),
#  ('wondering', 58),
#  ('club', 57),
#  ('francisco', 57),
#  ('volunteer', 57),
#  ('web', 57),
#  ('accessing', 56),
#  ('color', 56),
#  ('general', 56),
#  ('peer', 56),
#  ('think', 56),
#  ('wall', 56),
#  ('217', 55),
#  ('kid', 55),
#  ('scissors', 55),
#  ('tape', 55),
#  ('yahoo', 55),
#  ('years', 55),
#  ('6th', 54),
#  ('citation', 54),
#  ('gold', 54),
#  ('human', 54),
#  ('lower', 54),
#  ('todays', 54),
#  ('validation', 54),
#  ('company', 53),
#  ('event', 53),
#  ('john', 53),
#  ('publications', 53),
#  ('states', 53),
#  ('valley', 53),
#  ('bathroom', 52),
#  ('building', 52),
#  ('documents', 52),
#  ('forms', 52),
#  ('life', 52),
#  ('math', 52),
#  ('schedule', 52),
#  ('transfer', 52),
#  ('vietnamese', 52),
#  ('ya', 52),
#  ('credit', 51),
#  ('grade', 51),
#  ('house', 51),
#  ('illiad', 51),
#  ('publication', 51),
#  ('renewal', 51),
#  ('special', 51),
#  ('update', 51),
#  ('video', 51),
#  ('anything', 50),
#  ('barcode', 50),
#  ('bus', 50),
#  ('current', 50),
#  ('management', 50),
#  ('play', 50),
#  ('ready', 50),
#  ('reviewed', 50),
#  ('women', 50),
#  ('black', 49),
#  ('ill', 49),
#  ('libraries', 49),
#  ('psychology', 49),
#  ('related', 49),
#  ('reserving', 49),
#  ('thesis', 49),
#  ('wimpy', 49),
#  ('closed', 48),
#  ('directory', 48),
#  ('interested', 48),
#  ('ive', 48),
#  ('legal', 48),
#  ('medical', 48),
#  ('next', 48)]

# %% [markdown]
# You might also want to display similar frequency distribution on your own subset. This can be achieved using the following code:

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question', 'Answer', 'Email'])         # we are interested in question column
q.set_condition('Question NOT', 'null')       # Question should not be empty
q.set_condition('AND Answer NOT', 'null')     # 
q.set_condition('AND Email', 'kinglibraryreference@gmail.com')
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words
# Out:
# Columns:  ['Question', 'Answer', 'Email']
# Conditions:  [('Question NOT', 'null'), ('AND Answer NOT', 'null'), ('AND Email', 'kinglibraryreference@gmail.com')]
# Limit: 0
# [('book', 1226),
#  ('looking', 1132),
#  ('books', 1114),
#  ('computer', 915),
#  ('library', 711),
#  ('patron', 674),
#  ('find', 598),
#  ('need', 591),
#  ('print', 557),
#  ('help', 548),
#  ('wanted', 496),
#  ('card', 491),
#  ('get', 441),
#  ('student', 351),
#  ('use', 323),
#  ('number', 317),
#  ('room', 309),
#  ('needed', 299),
#  ('information', 264),
#  ('articles', 259),
#  ('phone', 237),
#  ('time', 232),
#  ('asked', 222),
#  ('know', 214),
#  ('printing', 213)]

# %% [markdown]
# This function can also be useful if we want to find out what are the most popular column values. Next example would show us the values of Tags, Difficulty, Format and Location columns.

# %% [markdown]
# #### Tags Column

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Tags'])                       # we are interested specified columns
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words
# Out:
# Columns:  ['Tags']
# Conditions:  []
# Limit: 0
# [('null', 26392),
#  ('laptop4h', 2526),
#  ('directional', 1875),
#  ('catalog', 1857),
#  ('books', 1750),
#  ('computer', 1686),
#  ('printing', 1653),
#  ('librarycard', 1087),
#  ('checkout', 1077),
#  ('book', 1049),
#  ('reference', 888),
#  ('public', 840),
#  ('student', 760),
#  ('newspapers', 695),
#  ('scanner', 657),
#  ('publiccomputers', 595),
#  ('card', 554),
#  ('fines', 534),
#  ('ipad4h', 521),
#  ('supplies', 507),
#  ('renewal', 461),
#  ('studyroom', 448),
#  ('coursereserves', 434),
#  ('computerassistance', 426),
#  ('account', 397)]
# Columns:  ['Tags']
# Conditions:  []
# Limit: 0
# [('null', 26392),
#  ('laptop4h', 2526),
#  ('directional', 1875),
#  ('catalog', 1857),
#  ('books', 1750),
#  ('computer', 1686),
#  ('printing', 1653),
#  ('librarycard', 1087),
#  ('checkout', 1077),
#  ('book', 1049),
#  ('reference', 888),
#  ('public', 840),
#  ('student', 760),
#  ('newspapers', 695),
#  ('scanner', 657),
#  ('publiccomputers', 595),
#  ('card', 554),
#  ('fines', 534),
#  ('ipad4h', 521),
#  ('supplies', 507),
#  ('renewal', 461),
#  ('studyroom', 448),
#  ('coursereserves', 434),
#  ('computerassistance', 426),
#  ('account', 397)]

# %% [markdown]
# #### Difficulty Column

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Difficulty'])                 # we are interested specified columns
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words
# Out:
# Columns:  ['Difficulty']
# Conditions:  []
# Limit: 0
# [('null', 63523)]

# %% [markdown]
# #### Format Column

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Format'])                     # we are interested specified columns
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 

mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words
# Out:
# Columns:  ['Format']
# Conditions:  []
# Limit: 0
# [('inperson', 54484),
#  ('remote', 9015),
#  ('phone', 7634),
#  ('email', 1381),
#  ('chat', 21),
#  ('skype', 21),
#  ('texting', 21),
#  ('virtual', 21),
#  ('roving', 3)]

# %% [markdown]
# #### Location Column

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Location'])                   # we are interested specified columns
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 

mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words
# Out:
# Columns:  ['Location']
# Conditions:  []
# Limit: 0
# [('floor', 29640),
#  ('2nd', 23595),
#  ('desk', 12368),
#  ('center', 7087),
#  ('periodicals', 6821),
#  ('welcome', 6255),
#  ('circulation', 6113),
#  ('3rd', 5829),
#  ('room', 4005),
#  ('computing', 3998),
#  ('student', 3998),
#  ('childrens', 3616),
#  ('call', 3089),
#  ('office', 1548),
#  ('level', 538),
#  ('lower', 538),
#  ('collections', 449),
#  ('sjsu', 449),
#  ('special', 449),
#  ('ca', 389),
#  ('mezzanine', 344),
#  ('administration', 322),
#  ('chc', 302),
#  ('1st', 211),
#  ('8th', 3)]

# %% [markdown]
# #### Email Column

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Email'])                   # we are interested specified columns
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 

mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words
# Out:
# Columns:  ['Email']
# Conditions:  []
# Limit: 0
# [('kinglibraryreferencegmailcom', 31483),
#  ('accessgimletgmailcom', 23255),
#  ('angiemiraflorsjlibraryorg', 3778),
#  ('studentcomputingservices1gmailcom', 3456),
#  ('emilychansjsuedu', 234),
#  ('teresaslobuskisjsuedu', 178),
#  ('dianawusjsuedu', 155),
#  ('crystalgoldmansjsuedu', 147),
#  ('tinapetersonsjsuedu', 144),
#  ('marcihunsakersjsuedu', 91),
#  ('valeriamoltenisjsuedu', 82),
#  ('juliekowalewskiwardsjsuedu', 80),
#  ('susankendallsjsuedu', 68),
#  ('silkehigginssjsuedu', 58),
#  ('danellemoonsjsuedu', 53),
#  ('rebeccafeindsjsuedu', 46),
#  ('berndbeckersjsuedu', 45),
#  ('mengxiongliusjsuedu', 43),
#  ('annageesjsuedu', 42),
#  ('berniceredfernsjsuedu', 38),
#  ('adrianapoosjsuedu', 20),
#  ('lindacrottysjsuedu', 20),
#  ('christinamunesjsuedu', 4),
#  ('sjsurovingreferencegmailcom', 3)]

# %% [markdown]
# ### Question_Time Column

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question_Time'])                   # we are interested specified columns
q.show = False                                # not displaying the result of this query on screen 
q.limit = 15                                   # allows us to take out the result limitations 

q.execute(con)
# Out:
# Columns:  ['Question_Time']
# Conditions:  []
# Limit: 15
# [('08:58:00 AM',),
#  ('08:59:00 AM',),
#  ('09:02:00 AM',),
#  ('09:08:00 AM',),
#  ('09:10:00 AM',),
#  ('09:16:00 AM',),
#  ('09:19:00 AM',),
#  ('09:20:00 AM',),
#  ('09:29:00 AM',),
#  ('09:29:00 AM',),
#  ('09:35:00 AM',),
#  ('09:50:00 AM',),
#  ('09:50:00 AM',),
#  ('09:50:00 AM',),
#  ('09:52:00 AM',)]

# %% [markdown]
# # Visualization

# %% [markdown]
# ###### MORE DOCUMENTATION NEEDED HERE

# %% [markdown]
# This small function can be tweaked to alter the default representation of pie-chart.

# %%
def pie_chart(info):
    labels = [l[0] for l in info]
    sizes = [l[1] for l in info]
    colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
    
    rcParams['figure.figsize'] = 10, 10
    
    plt.pie(sizes, labels=labels, colors=colors,
            autopct='%1.1f%%', shadow=True, startangle=90)
    
    plt.axis('equal')
    plt.show()

# %% [markdown]
# I also want to have a look at the most frequent words in our text-base in the form of pie chart. During the initialization the whole text-body was placed into text variable, which we would happily reuse here.

# %%
mfw = analyzer.get_most_frequest_words(text, 25)  # Return most frequent words 
pie_chart(mfw)                 # draw the pie chart

# %% [markdown]
# Due to the fact that 'null' value heavily bloats the graph, one may consider removing it from our dataset for research purpose.

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question', 'Email'])          # we are interested in question and email columns
q.set_condition('Question NOT', 'null')       # Question should not be empty
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 


mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequest_words(mytext, 25)  # Return most frequent words 
pie_chart(mfw)                                # draw the pie chart
# Out:
# Columns:  ['Question', 'Email']
# Conditions:  [('Question NOT', 'null')]
# Limit: 0

# %% [markdown]
# ### Prepare the dataset, merge synonyms

# %% [markdown]
# # Report

# %% [markdown]
# ## Question 1: Who is answering questions (library assistants, librarians, access services, etc.)

# %% [markdown]
# ## Question 2: What types of questions are people asking (level of question: directional, technical, etc.)

# %% [markdown]
# Basic approach would be to look at tags distribution in order to figure out the types (or rather topics) of questions  that people are frequently asking.

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Tags'])                       # we are interested specified columns
q.set_condition('Tags NOT', 'null')           # remove 'null' values, make the graph readable
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words 
pie_chart(mfw)
# Out:
# Columns:  ['Tags']
# Conditions:  [('Tags NOT', 'null')]
# Limit: 0

# %% [markdown]
# ## Question 3: Who is asking questions (majors, students from a particular class, general sjpl public)

# %% [markdown]
# ## Question 4: The percentage of questions for assistance with computer related help (making reservations,
#
# help using websites, using Microsoft products, etc.)

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Tags'])          # we are interested specified columns
q.set_condition('Tags NOT', 'null')
q.set_condition('AND Tags', 'computer')
q.set_condition('OR Tags', 'computerassistance')  # using the keyword 'OR' allows us to nest couple
q.set_condition('OR Tags', 'publiccomputers')     # of possible options together
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 

mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words 
pie_chart(mfw)
# Out:
# Columns:  ['Tags']
# Conditions:  [('Tags NOT', 'null'), ('AND Tags', 'computer'), ('OR Tags', 'computerassistance'), ('OR Tags', 'publiccomputers')]
# Limit: 0

# %% [markdown]
# ## Question 5: Identify student questions to see what types of information they needed, if a class session for a
#
# group of students is needed.

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question'])                   # we are interested specified columns
q.set_condition('Question', 'class')          # remove 'null' values, make the graph readable
q.set_condition('OR Question', 'student')
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words 
pie_chart(mfw)
# Out:
# Columns:  ['Question']
# Conditions:  [('Question', 'class'), ('OR Question', 'student')]
# Limit: 0

# %% [markdown]
# ## Question 6: What percentage of reference questions are being asked between 5 pm and 9
#
# am in each location?

# %%
import time

def percentage(part, whole):                  
  return 100 * float(part)/float(whole)

q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question_Time', 'Question'])  # we are interested specified columns
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
times = q.execute(con)

timef = "%I:%M:%S %p"
whole = 0
part = 0 
for each in times:   
    if time.strptime(each[0], timef) > time.strptime("05:00:00 PM", timef): 
        part += 1
    if time.strptime(each[0], timef) < time.strptime("09:00:00 AM", timef):
        part += 1
    whole +=1

print 'About', percentage(part, whole),'% of the questions are being asked in between 5pm and 9am'

info = [('between 5pm and 9am', part), ('Working hours',whole-part)]
pie_chart(info)
# Out:
# Columns:  ['Question_Time', 'Question']
# Conditions:  []
# Limit: 0
# About
#  16.332666908 % of the questions are being asked in between 5pm and 9am

# %% [markdown]
# ## Question 7: What percentage of directional questions concern meeting rooms, classrooms,
#
# bathrooms, study rooms, etc. Other locations?

# %%
# Out:
# Columns:  ['Email', 'Question', 'Answer', 'Format']
# Conditions:  [('Question', 'time is it'), ('AND Format', 'Phone')]
# Limit: 0
# [('kinglibraryreference@gmail.com',
#   'what time is it',
#   'null',
#   'Phone (Remote)'),
#  ('kinglibraryreference@gmail.com',
#   'What time is it?',
#   'null',
#   'Phone (Remote)'),
#  ('kinglibraryreference@gmail.com',
#   'What time is it?',
#   'null',
#   'Phone (Remote)')]

# %%
q = backend.QueryBuilder()
q.set_columns(['Answer', 'Question'])
q.set_condition('Question', 'meeting room')
q.set_condition('OR Question', 'classroom')
q.set_condition('OR Question', 'bathrooms')
q.set_condition('OR Question', 'study room')
q.limit = 25


mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words 
pie_chart(mfw)
# Out:
# Columns:  ['Answer', 'Question']
# Conditions:  [('Question', 'meeting room'), ('OR Question', 'classroom'), ('OR Question', 'bathrooms'), ('OR Question', 'study room')]
# Limit: 25

# %% [markdown]
# ## Question 8: Order the tags by usage. List related questions with tags. For instance: tag:
#
# computers. List questions assigned to tag including tags with no questions.

# %% [markdown]
# ## Question 9: What percentage of technical (computer) questions fall into categories i.e. IT
#
# issues, login, application help (Microsoft), website?

# %% [markdown]
# ### Funny stuff

# %%
q = backend.QueryBuilder()
q.set_columns(['Email', 'Question', 'Answer', 'Format'])
q.set_condition('Question', 'time is it')
q.set_condition('AND Format', 'Phone')
q.limit = 0
q.execute(con)
q.display(['Email', 'Question'])
# Out:
# Columns:  ['Email', 'Question', 'Answer', 'Format']
# Conditions:  [('Question', 'time is it'), ('AND Format', 'Phone')]
# Limit: 0
# kinglibraryreference@gmail.com
# what time is it
# kinglibraryreference@gmail.com
# What time is it?
# kinglibraryreference@gmail.com
# What time is it?

# %%
q.execute(None)
# Out:
# Columns:  ['Email', 'Question', 'Answer', 'Format']
# Conditions:  [('Question', 'time is it'), ('AND Format', 'Phone')]
# Limit: 0
# SELECT Email, Question, Answer, Format FROM gimlet_csv WHERE Question LIKE '%time is it%' AND Format LIKE '%Phone%'

# %% [markdown]
# # Ending the session

# %% [markdown]
# Last thing that we should do is to close the connection to the database, thus ending our session.

# %%
#con.close()
