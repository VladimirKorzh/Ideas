# %%
from notebook import execute_notebook

# %%
execute_notebook("IDEAS_Initialize.ipynb")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'backend' from 'backend.pyc'>
# <module 'nltk' from 'C:\Users\vladimir\Anaconda\lib\site-packages\nltk\__init__.pyc'>
# Reading input data files from C:\Users\vladimir\Documents\GitHub\Ideas\Idea\dataset
# Found GimletDownload2012_07.csv ... 2595  records imported
# Found GimletDownload2012_08.csv ... 3672  records imported
# Found GimletDownload2012_09.csv ... 3817  records imported
# Found GimletDownload2012_10.csv ...
# 13595  records imported
# Found GimletDownload2012_11.csv ...
# 14737  records imported
# Found GimletDownload2012_12.csv ... 9696  records imported
# Found GimletDownload2013_01.csv ...
# 5820  records imported
# Found GimletDownload2013_02.csv ... 9599  records imported
#
# Creating database layout...
# Table created.
#
# Inserting data into database...
# Done.
# Querying the total amount of rows imported
# Columns:
#  ['*']
# Conditions:  []
# Limit: 0
# Total amount of questions imported 63523

# %%
execute_notebook("IDEAS_Preprocessing_data.ipynb")

# %%
text = analyzer.db_get_full_text(con)
# Out:
# Analyzing questions text-body... Done.

# %%
text
# Out:
# ' log problems room 213 account question fine pick requested item phonenumber nicole nu\xc3\xb1ez change branch page shows default access library website remember choosing first place joyce ellington use different branch rose garden cant figure make page one shows plans purchase audio book format michael vey prisoner cell 25 richard paul evans put usb slots user name comp log happens put hold item need advice turabian citations magazines reserve study room restroom needed computer get craigslist librarycard card expired havet 4 years looking book lincoln wanted request beloved world sotomayor boxing injuries buy print card needed audio books spanish someone trying pass citizenship test looking books oil industry newspaper sanjose mercury news problems downloaded overdrive book 219 computer connecting server send print wheres chinese movies government publications book ll 03 1980s copy good housekeeping magazine study room good housekeeping 19801986 sign computer log onto computer get craigslist wheres learning spanish books study room computer assistance question download book oneclick digital helping attach file online resume wanted put hold book smokingsearch one nubs true story dog computer says librarycard needs renewed advisory ppl coming downstairs film 3rd floor get librarycard would like book books 247 downloadable need get kate turabians manual im grad student book due quickly womens indian captivity narratives help filling application alalowed bring magazines floors free tax help title search grave matters excavating californias buried past list used car dealers sanjose copier machine problems misfeed print cash room 213 room 217 rm 213 biography need phonenumber daily donuts cunnyvalesaratoga picture books tax help kl scanner bio printing looking finding nemo set print list refusa cant find book made study room reservation dont know floor borrow pen newspaper scanner 1800 amtrak at04 login email usb computer assistance scanner im looking ap computer science book borrow pen time julienne cut center assistive technology im trouble sending resume email computer im using went site downloaded book everything exactly ive done many books however never arrived kindle doesnt show bookbag amazon account programs babys librarycard mission books sheet music location book computer spell encouragement get mtview best buy milpitas details library grants definitions aristocracy plutocracy kleptocracy tax help king couldnt renew ipads online trying find adea official guide dental schools type services ebook support person started ask question phonenumber lookup decided call back put box filling online form use add value machine looking info santa clara county canneries slid card check balance find much print card computer telling account blocked information boxing injuries looking historical info santa clara county fairgrounds assistance finding journal article california history journal help photocopying 2 textbooks lookup patron needs information coursework previous sanjosestateuniversity catalogs copied sent rm 217 eat mezzanine newspaper wherere videos vietnamese chinese languages computerassistance restroom customer needed help transferring information disc cell phone computer assistance scanner study room newspaper san francisco chronicle whiteout supplies email assistance looking sanjosestateuniversity reserved book looking ca yearbook customer needed librarycard renewed login customer needed time extension books writing styles myths fantasy therapeutic guide herbal medicines guys payphones assistance use reference usa searching question patron wants help changing yahoo mail language hindi english understanding using english grammar fundamentals english grammar copyediting proofreading dummies powerful proofreading skills longman dictionary american english step step word 2010 252 number talks war sexes beyond human nature patron wants find dvd help make mexican dishes patron wanting know whether adobe illustrator photoshop p ...

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['text']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
bigrams = nltk.bigrams(text)
cfd = nltk.ConditionalFreqDist(bigrams)

cfd.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-b454345c0e3b> in <module>()
# ----> 1 bigrams = nltk.bigrams(text)
#       2 cfd = nltk.ConditionalFreqDist(bigrams)
#       3
#       4 cfd.plot()
#
# C:\Users\vladimir\Anaconda\lib\site-packages\nltk\util.pyc in bigrams(sequence, **kwargs)
#     437     :rtype: list(tuple)
#     438     """
# --> 439     return ngrams(sequence, 2, **kwargs)
#     440
#     441 def trigrams(sequence, **kwargs):
#
# C:\Users\vladimir\Anaconda\lib\site-packages\nltk\util.pyc in ngrams(sequence, n, pad_left, pad_right, pad_symbol)
#     418     if pad_right:
#     419         sequence = chain(sequence, (pad_symbol,) * (n-1))
# --> 420     sequence = list(sequence)
#     421
#     422     count = max(0, len(sequence) - n + 1)
#
# TypeError: 'function' object is not iterable

# %%
text = analyzer.db_get_full_text(con)   # this takes into account every question that is loaded
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = nltk.collocations.BigramCollocationFinder.from_words(text)
finder.apply_freq_filter(3)
finder.apply_word_filter(filter_stops)
matches1 = finder.nbest(bigram_measures.pmi, 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-127-b3df8e441421> in <module>()
#       4 finder = nltk.collocations.BigramCollocationFinder.from_words(text)
#       5 finder.apply_freq_filter(3)
# ----> 6 finder.apply_word_filter(filter_stops)
#       7 matches1 = finder.nbest(bigram_measures.pmi, 20)
#
# NameError: name 'filter_stops' is not defined
# Analyzing questions text-body... Done.

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question'])         # we are interested in question column
q.set_condition('Question ', 'sanjose')       # Question should not be empty
q.limit = 5                                  # allows us to take out the result limitations 
q.execute(con)
# Out:
# Columns:  ['Question']
# Conditions:  [('Question ', 'sanjose')]
# Limit: 5
# [('i am going on sanjoselibrary.org and i cant access refusa',),
#  ('council on aging in sanjose',),
#  ("i was using the san-jose-state-university database and i found an article of interest. however the link (get text) doesn't work, i was hoping maybe you could help me get access.    here's the link,     http://library.calstate.edu/sanjose/metasearch/record?group=2012-09-22-002226&resultset=045842&startrecord=000001&return=%2fsanjose%2fmetasearch%2ffacet%3fgroup%3d2012-09-22-002226%26amp%3bresultset%3d045863%26amp%3bfacet%3d6%26amp%3bnode%3d2    thank you!",)]

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question'])                   # we are interested in question column
q.set_condition('Question', 'number')         # Question should not be empty

#q.show = False                                # not displaying the result of this query on screen 
q.limit = 25                                   # allows us to take out the result limitations 
q.execute(con)
#mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
#analyzer.get_most_frequent_words(mytext, 25)  # Print most frequent words
# Out:
# Columns:  ['Question']
# Conditions:  [('Question', 'number')]
# Limit: 25
# [('phone-number for nicole nu\xc3\xb1ez',),
#  ('need phone-number for daily donuts on cunnyvale/saratoga',),
#  ('person started to ask a question about a phone-number lookup but decided to call back.',),
#  ('number talks',),
#  ('call number check hq etc.',),
#  ('stubhub phone-numbers',),
#  ('found the loc call number for a item searched as dewey from a branch ',),
#  ("what is the dewey number is for women's hats",),
#  ('customer wanted  help with pin-number ',),
#  ('need address and numbers for tasters choice, nestle, coffee association of america, and description on freeze drying process for coffee',),
#  ('customer wanted help to reset pin-number ',),
#  ('number for senior living on meridan',),
#  ('number and address for camping sites in capitola',),
#  ('i just logged on and it says that i am still number 11 on the waiting list. however i recieved an e-mail saying my hold is available. is this a mistake? i do not want to lose my spot in the waiting list.',),
#  ('needed phone-number for local chapter for seiu, santa clara county',),
#  ('phone-number for the fusion and contacts center in scottsdale, az',),
#  ('wrong number call.',),
#  ("had call number couldn't find book ",),
#  ('bascom community center phone-number',),
#  ('caller needs the telephone-number for san-jose convention center',),
#  ('telephone-number for dmv',),
#  ('what is the number for wifi?',),
#  ('library-card number',),
#  ('customer needed phone-number of her former doctor',),
#  ('my san-jose library-card was lost. the card number (san-josepl barcode) is 21197.... can we cancel that card and get a replacement card?',)]
