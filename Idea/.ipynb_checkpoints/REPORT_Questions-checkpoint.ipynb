# %%
from notebook import execute_notebook

# %%
execute_notebook("IDEAS_Initialize.ipynb")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'backend' from 'backend.pyc'>
# <module 'nltk' from 'C:\Users\vladimir\Anaconda\lib\site-packages\nltk\__init__.pyc'>
# Reading input data files from C:\Users\vladimir\Documents\GitHub\Ideas\Idea\dataset
# Found GimletDownload2012_07.csv ... 2595  records imported
# Found GimletDownload2012_08.csv ... 3672  records imported
# Found GimletDownload2012_09.csv ... 3817  records imported
# Found GimletDownload2012_10.csv ...
# 13595  records imported
# Found GimletDownload2012_11.csv ...
# 14737  records imported
# Found GimletDownload2012_12.csv ...
# 9696  records imported
# Found GimletDownload2013_01.csv ... 5820  records imported
# Found GimletDownload2013_02.csv ...
# 9599  records imported
#
# Creating database layout...
# Table created.
#
# Inserting data into database...
# Done.
# Querying the total amount of rows imported
# Total amount of questions imported
#  63523

# %%
execute_notebook("IDEAS_Preprocessing_data.ipynb")

# %% [markdown]
# ## Most frequent words

# %%
textbody = analyzer.db_get_full_text(con)
mfw = analyzer.get_most_frequent_words(textbody, 25)  # Return most frequent words 
pie_chart(mfw)                                        # draw the pie chart
# Out:
# Analyzing questions text-body... Done.

# %% [markdown]
# ## What percentage of reference questions are being asked between 5 pm and 9
#
# am in each location?

# %%
def percentage(part, whole):                  
	return 100 * float(part)/float(whole)		

q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question_Time', 'Question','Location'])  # we are interested specified columns
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
times = q.execute(con)

timef = "%I:%M:%S %p"
whole = 0
part = 0 
for each in times:   
    if time.strptime(each[0], timef) > time.strptime("05:00:00 PM", timef): 
        part += 1
    if time.strptime(each[0], timef) < time.strptime("09:00:00 AM", timef):
        part += 1
    whole +=1

print 'About', percentage(part, whole),'% of the questions are being asked in between 5pm and 9am'

infostats = [('between 5pm and 9am', part), ('Working hours',whole-part)]
pie_chart(infostats)
# Out:
# About 16.332666908 % of the questions are being asked in between 5pm and 9am

# %% [markdown]
# ## The percentage of questions for assistance with computer related help (making reservations,
#
# help using websites, using Microsoft products, etc.)

# %%
backend.replace(con, 'Question', 'public computer', 'public-computer')
backend.replace(con, 'Question', 'rac', 'reserve-a-computer')

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question'])                       # we are interested specified columns
q.set_condition('Question', 'computer')
#q.set_condition('OR Tags', 'computerassistance')  # using the keyword 'OR' allows us to nest couple
#q.set_condition('OR Tags', 'publiccomputers')     # of possible options together
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                 # allows us to take out the result limitations 

mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequent_words(mytext, 25)  # Print most frequent words 
mfw = mfw[1:]
pie_chart(mfw)

# %% [markdown]
# ## Who is answering questions (library assistants, librarians, access services, etc.)

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Tags'])                       # we are interested specified columns
#q.set_condition('Tags NOT', 'null')           # remove 'null' values, make the graph readable
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequent_words(mytext, 25)  # Print most frequent words 
pie_chart(mfw)

# %% [markdown]
# ## What types of questions are people asking (level of question: directional, technical, etc.)

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Tags'])                       # we are interested specified columns
q.set_condition('Tags NOT', 'null')           # remove 'null' values, make the graph readable
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequent_words(mytext, 25)  # Print most frequent words 
pie_chart(mfw)

# %% [markdown]
# Another approach.

# %%
q = backend.QueryBuilder()                    # Create a new custom query
q.set_columns(['Question_Type', 'Question'])                       # we are interested specified columns
q.set_condition('Question_Type', 'directional')
q.set_condition('Question NOT', 'null')
q.show = False                                # not displaying the result of this query on screen 
q.limit = 0                                   # allows us to take out the result limitations 
q.execute(con)

#mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
#mfw = analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words 
#pie_chart(mfw)
# Out:
# [('directional', 'log in problem'),
#  ('directional', 'room 213 ?'),
#  ('directional', 'account question ( fine for no pick up of requested item )'),
#  ('directional', 'phone-number for nicole nu\xc3\xb1ez'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'can i put my usb into any of the slot ?'),
#  ('directional', 'what is user name for comp log in ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'what happens when i put a hold on an item ?'),
#  ('directional', 'null'),
#  ('directional', 'magazine'),
#  ('directional', 'how to reserve study-room ?'),
#  ('directional', 'restroom'),
#  ('directional', 'null'),
#  ('directional', 'needed computer to get on craigslist ; no library-card'),
#  ('directional', 'null'),
#  ('directional', 'where buy print card'),
#  ('directional', 'newspaper san-jose mercury-news'),
#  ('directional', 'had problem with downloaded overdrive book'),
#  ('directional', "where 's the chinese movie"),
#  ('directional', 'government publication'),
#  ('directional', 'how to log onto computer and get on craigslist'),
#  ('directional', "where 's the learning spanish book"),
#  ('directional', 'null'),
#  ('directional', 'computer say library-card need to be renewed'),
#  ('directional',
#   'advisory that ppl will be coming downstairs to film ( from 3rd floor )'),
#  ('directional', 'where do i get a library-card ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'am i alalowed to bring magazine to other floor ?'),
#  ('directional', 'free tax help ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "copier machine problem ; `` misfeed ''"),
#  ('directional', 'null'),
#  ('directional', 'rm 213'),
#  ('directional', 'null'),
#  ('directional', 'need phone-number for daily donut on cunnyvale/saratoga'),
#  ('directional', 'picture book where'),
#  ('directional', 'null'),
#  ('directional', 'bio'),
#  ('directional', 'null'),
#  ('directional', "i ca n't find this book"),
#  ('directional', 'newspaper'),
#  ('directional', '1800 for amtrak'),
#  ('directional', 'where is at04 ?'),
#  ('directional', 'center for assistive technology'),
#  ('directional', 'null'),
#  ('directional', 'program for baby ?'),
#  ('directional', 'library-card ?'),
#  ('directional', 'mission book'),
#  ('directional', 'how do you spell encouragement ?'),
#  ('directional', 'how do i get to mtview best buy from milpitas'),
#  ('directional', 'null'),
#  ('directional', 'tax help at king'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'person started to ask a question about a phone-number lookup but decided to call back .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is rm # 217 ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'can we eat in the mezzanine ?'),
#  ('directional', 'newspaper'),
#  ('directional', "where 're your video in vietnamese and chinese language ?"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'restroom'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'study-room'),
#  ('directional', 'newspaper san-francisco chronicle'),
#  ('directional', 'white-out supply'),
#  ('directional', 'looking for this san-jose-state-university reserved book'),
#  ('directional', 'looking for a ca yearbook .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'do you guy have payphones'),
#  ('directional', 'where is 2-52'),
#  ('directional', 'looking for the cbest book'),
#  ('directional', 'where are the vietnamese dvd'),
#  ('directional', 'where is hm1'),
#  ('directional', 'do you have pencil and scratch paper ?'),
#  ('directional', 'null'),
#  ('directional', 'location of geronimo stilton series'),
#  ('directional', 'returning kl book at other location'),
#  ('directional', 'lost item'),
#  ('directional', 'spanish language childrens book'),
#  ('directional', 'location of dictionary & thesaurus'),
#  ('directional', '7th grade textbook in various subject'),
#  ('directional', 'where do i check out'),
#  ('directional', 'library-card'),
#  ('directional',
#   'need to find hard copy of nursing journal on a specific topic'),
#  ('directional', 'where is the restroom ?'),
#  ('directional', "men 's restroom is out of toilet paper"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'patron wanted to look at the map of the library'),
#  ('directional',
#   'where is your section of foriegn language childrens book ? ?'),
#  ('directional', "where 's computer 2-53 ?"),
#  ('directional', 'null'),
#  ('directional', 'where is the young adult area ?'),
#  ('directional', 'do you have a pencil sharpener ?'),
#  ('directional', 'can we take the childrens book to other floor ? ?'),
#  ('directional', 'null'),
#  ('directional', 'where do i check out ?'),
#  ('directional', 'do you have book on montana ?'),
#  ('directional', 'where is ll'),
#  ('directional', 'do you have spanish childrens book ? ?'),
#  ('directional', 'when do you have tax help ?'),
#  ('directional', 'available computer'),
#  ('directional', 'gov pub help'),
#  ('directional', 'null'),
#  ('directional',
#   'found the loc call number for a item searched a dewey from a branch'),
#  ('directional', 'null'),
#  ('directional', 'looking for mission book'),
#  ('directional', 'gov pub item couldnt find'),
#  ('directional', 'needed help with logging on to computer'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is j pb section'),
#  ('directional', 'help locating a music book on 5th floor'),
#  ('directional', 'null'),
#  ('directional', 'need la time from 2008'),
#  ('directional', 'info about parking at king-library'),
#  ('directional', 'checkout'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'looking for tavel book'),
#  ('directional', "looking for bio 's book"),
#  ('directional', 'looking for math geometry'),
#  ('directional', 'looking for test book'),
#  ('directional', 'do you have a 3-hold punch ?'),
#  ('directional', 'null'),
#  ('directional', 'looking for general george patton book'),
#  ('directional', 'looking for book on the wright borthers'),
#  ('directional', 'null'),
#  ('directional', 'patron looking for minum wage rate by state'),
#  ('directional', 'patron had question about book that wa lying on desk'),
#  ('directional', 'null'),
#  ('directional', 'where are your reading list for kid ?'),
#  ('directional', 'where is your chapter series book ?'),
#  ('directional', 'where do i check out ?'),
#  ('directional', "looking for today 's ny time"),
#  ('directional', 'null'),
#  ('directional', 'do you have any more book on chinese new year ?'),
#  ('directional', 'where do i check out ?'),
#  ('directional', 'null'),
#  ('directional', 'where do i checkout'),
#  ('directional', 'info about volunteering'),
#  ('directional', 'where are chapter book for 5th grade'),
#  ('directional', 'kid dvd - where are they and what is loan period'),
#  ('directional', 'where is computer 2-54 ?'),
#  ('directional', 'do you have this paperback ?'),
#  ('directional', 'null'),
#  ('directional',
#   'can you help me connecting to the campus wireless internet ?'),
#  ('directional', 'science experiment book for kindergartener'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where do i checkout'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where are your easy reader section ? ?'),
#  ('directional', 'where are your poetry book ?'),
#  ('directional', 'where is there a copy-machine'),
#  ('directional', 'can i get some paper towel to clean off the computer'),
#  ('directional', 'looking for vietnamese magazine'),
#  ('directional',
#   "how do i use the study-room upstairs ? i 'm a student , but no one is here ."),
#  ('directional', 'where do you go to renew your library-card ?'),
#  ('directional',
#   'where can i get more movie , but not so babyish ? appropriate for kid , but not so young ?'),
#  ('directional', 'can you help me look up my library barcode ?'),
#  ('directional', 'where can i get a library-card ?'),
#  ('directional', 'do i check out the book here ?'),
#  ('directional', 'where can i checkout my book ?'),
#  ('directional', 'is this magazine ( free giveaway material ) free ?'),
#  ('directional', 'what are your open hour ?'),
#  ('directional',
#   "need to access to a computer but did n't bring his library-card w/him"),
#  ('directional', 'a patron reporting his bag got stolen'),
#  ('directional', 'patron looking for bag left behind yesterday'),
#  ('directional', 'where are your biography ?'),
#  ('directional', 'customer wanted help with pin-number'),
#  ('directional', 'patron needed to use scanner'),
#  ('directional', 'where russian book ?'),
#  ('directional',
#   "computer wa n't completing log-on and mouse wasnt working right"),
#  ('directional', 'patron needed add value machine'),
#  ('directional', 'where are the comic book ?'),
#  ('directional', 'patron needed color printing'),
#  ('directional', 'can you lower the screen on the w. side ?'),
#  ('directional', 'where are the animal book located ?'),
#  ('directional', 'scotch tape supply'),
#  ('directional', 'customer wanted help to reset pin-number'),
#  ('directional', "patron looking for a book , did n't find it on shelf"),
#  ('directional', 'follow-up to question about libguides .'),
#  ('directional', 'how do you access the wifi ?'),
#  ('directional', 'null'),
#  ('directional', 'is it possible to check out headphone ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'customer looking for popular mechanic & popular science'),
#  ('directional', 'pen supply'),
#  ('directional', 'null'),
#  ('directional', 'can i find a specific news article ?'),
#  ('directional', 'how do i get on your computer'),
#  ('directional', 'photo copy assistance'),
#  ('directional',
#   'benjamin needed some help taping somwething to his notebook'),
#  ('directional',
#   "`` i am using my girl 's library-card , i dont ' know the pin ''"),
#  ('directional', 'new business listing ?'),
#  ('directional',
#   'customer had question about placement of title within a series of government document'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where can i use a computer ?'),
#  ('directional', 'null'),
#  ('directional', 'where renew library-card ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is computer 43 on third floor'),
#  ('directional', 'can youi break a 50 dollar bill ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'my pdf is not showing up at the print station'),
#  ('directional', 'question about getting on a computer access'),
#  ('directional', 'do you have the yolo yellow page'),
#  ('directional', 'phone book'),
#  ('directional', 'phone book'),
#  ('directional', 'null'),
#  ('directional', "how do you spell `` warrior ''"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'copier location'),
#  ('directional', 'printing assistance'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'room 213 ?'),
#  ('directional', 'null'),
#  ('directional', 'do you allow food ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'what time doe the library close ?'),
#  ('directional', 'horoscope'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'when is the reading today'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is 217'),
#  ('directional', 'transfer to partner in reading'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'looking for computer 2-55 ; how add money to tower-card'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is room 219 ?'),
#  ('directional', 'where to reserve a computer ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "where do you have the child 's french book"),
#  ('directional', 'null'),
#  ('directional', 'printer'),
#  ('directional', 'is reading buddy supposed to start at 4:00 ?'),
#  ('directional', 'null'),
#  ('directional', 'where is 217 ?'),
#  ('directional', 'explain this drawing'),
#  ('directional', 'null'),
#  ('directional', 'couse reserve'),
#  ('directional', '213 and 219'),
#  ('directional', 'handbook of crime and punishment'),
#  ('directional', 'where is 2-43'),
#  ('directional', 'someone is on my computer ?'),
#  ('directional', 'do you know the hour for the bascom library ?'),
#  ('directional', 'null'),
#  ('directional', 'can we check out here ?'),
#  ('directional', 'null'),
#  ('directional', 'where are course reverves'),
#  ('directional', 'looked for california politics'),
#  ('directional', 'null'),
#  ('directional', 'where do i go for this ( social worker in the library ) .'),
#  ('directional',
#   'customer standing by desk with bunch of book , obviously wanting to check out ... . implicit question : where do we go to check out ?'),
#  ('directional', 'where are book to learn english'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'customer asked to checkout a book ?'),
#  ('directional', 'where can i checkout these book ?'),
#  ('directional', 'how late the library is open to the public tonight ?'),
#  ('directional',
#   'customer wanted a public-computer with access to floppy disk'),
#  ('directional', 'where is the section for shakespeare play ?'),
#  ('directional', 'null'),
#  ('directional', 'user asked how to reserve study-room .'),
#  ('directional',
#   'do you the book ruby holler , the word eater , and the gary soto short story blue guitar blue ?'),
#  ('directional', 'where is the book section on wwii ?'),
#  ('directional', 'charging station for phone'),
#  ('directional', 'looking to buy a print card'),
#  ('directional', 'null'),
#  ('directional', "looking for `` fight club ''"),
#  ('directional', 'where is room 322 ?'),
#  ('directional', 'looking for geisha related book .'),
#  ('directional', 'null'),
#  ('directional', 'customer had trouble logging into computer'),
#  ('directional',
#   "san-jose telepehone book wa the subject of a customer 's desire"),
#  ('directional',
#   "i have a question about my laptop. i keep getting a screen saver from cisco , asking for my login info. i do n't have a cisco account..i ca n't use my laptop ."),
#  ('directional',
#   'patron ( third visit ) wa looking for learn a language section on third floor .'),
#  ('directional', 'have you a pencil ?'),
#  ('directional',
#   'i downloaded the audiobook program and the audiobook ... the audio book say it is corrupt whenever i try to open it .'),
#  ('directional', 'do you have bible on this floor ?'),
#  ('directional',
#   'looking for computer class , life near the berryesa library .'),
#  ('directional', 'company look up xilinx .'),
#  ('directional', 'null'),
#  ('directional', 'music cd'),
#  ('directional', 'can we use a meeting room .'),
#  ('directional', 'null'),
#  ('directional', 'free tax form ?'),
#  ('directional', 'people on the go , need to cancel a request .'),
#  ('directional', 'null'),
#  ('directional',
#   'needed phone-number for local chapter for seiu , santa-clara county'),
#  ('directional',
#   'looking for san-josepl policy on the san-josepl webite and a strategic plan .'),
#  ('directional', 'deborah called asking about ebrary account .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', '2013 tax form ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "where 's waldo book"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "question about our child 's program"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'hello , i am trying to gain access to the database to retrieve required reading material for a geology class i am taking and am not able to log in. my name is jeana lopez ( former maiden last name : drennon ) and my studend id is 003820259. i do not know if i ever created a pin and if so , i do not remember it. can you help in any way ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   "patron looking for marci. ( said he 's a friend of marci 's . )"),
#  ('directional', 'null'),
#  ('directional', 'atlas/roadmaps - usa'),
#  ('directional', 'wrong number call .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where to buy copy card'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'i have to read to article for class and can not find them anywhere. it is a \xe2\x80\x9cscience\xe2\x80\x9d article : science-215 : 1501-1503 , title of article : mass extinction in the marine fossil record written by david m. raup and j. j sepkoski in 1982. the other is from the annual review of early and planetary science 34 : 127-155 , titled , phanerozoic biodiversity mass extinctions. any idea of where i can find these ?'),
#  ('directional', 'null'),
#  ('directional', 'check out book ?'),
#  ('directional', 'scrap paper + pencil ?'),
#  ('directional', 'room 217 ?'),
#  ('directional', 'how do i contact emily chan , the librarian ?'),
#  ('directional', 'null'),
#  ('directional', "had call number could n't find book"),
#  ('directional', 'looking for series title'),
#  ('directional', 'where do i check out ?'),
#  ('directional', 'null'),
#  ('directional', 'paperclip ?'),
#  ('directional', 'california room'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'computer assistance for friend'),
#  ('directional', 'location of study-room'),
#  ('directional', 'san-jose-state-university study area'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "polk 's directory"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is the ca room ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'california room ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how do i get a library-card ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'patron dispute w/ another patron ; called security to sort it out'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "where 's sf/fan book ?"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'looking for toby matoush for a meeting .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where are the mission book ?'),
#  ('directional', 'acadmeic reserve book'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'i am trying to download ... and get a san error message. please advise .'),
#  ('directional', 'where is room 217 ( x2 ) ?'),
#  ('directional', 'room 217 ? - several time'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how to get a library-card'),
#  ('directional', 'null'),
#  ('directional', 'where is 2-47 ?'),
#  ('directional', 'room 213 and 217'),
#  ('directional', 'looking for a historical photo of a school in santa-clara'),
#  ('directional',
#   'where is a place where you can scan your document and print it out'),
#  ('directional', '217 ?'),
#  ('directional', '217 ?'),
#  ('directional', '217 ?'),
#  ('directional', 'got a call that someone turned in my key ?'),
#  ('directional', 'help with change of address form , not computer savvy ...'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'what is the number for wifi ?'),
#  ('directional', 'ecology book'),
#  ('directional', 'wheres is the calendar mystery book ?'),
#  ('directional', 'change for $ 20'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where are spanish magazine'),
#  ('directional', 'do i check out book here ?'),
#  ('directional', 'null'),
#  ('directional', 'is there a new study area here ?'),
#  ('directional', 'finding gmat book'),
#  ('directional', 'do you loan out calculator ?'),
#  ('directional', 'where to add money to my card ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "6th floor men 's bathroom flooded"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'where do i go to schedule a meeting or event in the library ?'),
#  ('directional', 'null'),
#  ('directional', 'what are special collection ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'just want to search for some book'),
#  ('directional', 'null'),
#  ('directional', 'assisted patron with locating public pc'),
#  ('directional', 'null'),
#  ('directional', 'can you help me find this book j 636.783 ?'),
#  ('directional',
#   "patron looking for a book in the `` d '' section on 6th floor ."),
#  ('directional',
#   'alerted security after observing customer talking out louad about throwing acid on people , or burning in acid , or other such balderwash .'),
#  ('directional', 'learning spanish language book ?'),
#  ('directional', 'civil service book on accounting ?'),
#  ('directional', 'student on a scavenger hunt were looking for a globe'),
#  ('directional', 'null'),
#  ('directional', 'where is the bill breaker ?'),
#  ('directional',
#   'customer wa sleeping in the aisle..completley blocking the aisle. called security .'),
#  ('directional', 'null'),
#  ('directional', 'book -- history of economics'),
#  ('directional', 'recycle paper to use'),
#  ('directional', 'why do you people still have floppy disc .'),
#  ('directional', 'english language periodical'),
#  ('directional',
#   'parent wa looking for her daughter who is a volunteer for the library .'),
#  ('directional', "what event are there in the child 's exploration room ?"),
#  ('directional', 'where to check-out material .'),
#  ('directional',
#   'looking for book on genetics , psychology & psychiatry and the scc medical association directory .'),
#  ('directional', 'where do i check out book ?'),
#  ('directional', 'need help locating a book .'),
#  ('directional', 'null'),
#  ('directional',
#   "par meeting in the child 's exploration room. where is it ?"),
#  ('directional', 'do you have phone book'),
#  ('directional', 'null'),
#  ('directional', 'where are the nclex book located ?'),
#  ('directional', 'where is the express room ?'),
#  ('directional', 'where is 455 ?'),
#  ('directional', 'where is room 213 ?'),
#  ('directional', 'student looking for room 213 ?'),
#  ('directional', "looking for child 's party activity idea"),
#  ('directional', 'checkout ?'),
#  ('directional', "where 're book in the 780s ?"),
#  ('directional', 'null'),
#  ('directional', "ca n't get to full text of google scholar from home ."),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'do you have pay phone ?'),
#  ('directional', 'need a dictonary .'),
#  ('directional', 'where is fiction ?'),
#  ('directional', 'daily weather report'),
#  ('directional', 'where are the atlas ? especially the rand mcnally ?'),
#  ('directional', 'how can i display and showcase book ?'),
#  ('directional', 'address of library'),
#  ('directional', 'headphone ?'),
#  ('directional', 'room 213 ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', '213'),
#  ('directional', 'null'),
#  ('directional',
#   'electrical engineering student : specific database for his area'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how do find library job with the city'),
#  ('directional', 'where are ya non-fiction book ?'),
#  ('directional', 'null'),
#  ('directional', 'chinese book & newspaper'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'car repair manual ?'),
#  ('directional', 'null'),
#  ('directional',
#   "there 's an author here today , where do we go to hear her speak"),
#  ('directional', 'null'),
#  ('directional', 'iphone charger ?'),
#  ('directional', 'null'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'cost to get a library-card ? and where do i get one ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'can i check book out from the 7th floor ?'),
#  ('directional', 'where do i check out book ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'tax help available ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'scissors ?'),
#  ('directional', 'course assignment to see what this space is all about .'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'a student came in looking to talk to danelle about a project for her class. more specifically interested in local winery .'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'null'),
#  ('directional',
#   'woman came in asking about meeting with a group next thursday from korea about orchestral related ... stuff. ( she had a thick accent . )'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'null'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'do we have to show our tower-card every time we come ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'appt ?'),
#  ('directional',
#   'how did you hear about student learning and reseach common ?'),
#  ('directional', 'another copy of the certificate of naturalization ?'),
#  ('directional', 'piece of tape plez ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'follow-up to question about access to fdo database .'),
#  ('directional', 'looking for judy moody book'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'bathroom ?'),
#  ('directional', 'null'),
#  ('directional', 'looking where to buy a copy card'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is the magazine'),
#  ('directional', 'when doe the next session of chinese computer class start'),
#  ('directional', 'null'),
#  ('directional',
#   "need this book 'understanding physical , health , and multiple disability '"),
#  ('directional', 'null'),
#  ('directional', 'lost a pair of sunglass where is the lost and found'),
#  ('directional',
#   'phone request about this book : understanding physical , health , and multiple disability'),
#  ('directional', 'follow-up to question about searching technique .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'book held at account desk'),
#  ('directional', 'where english movie dvd ?'),
#  ('directional', 'dvd - feature film'),
#  ('directional', 'patron turned in found library-card'),
#  ('directional', 'how do i sign up for tour of beethoven center ?'),
#  ('directional', 'check out here ?'),
#  ('directional', 'patron called about lost rx sunglass'),
#  ('directional', 'where do i get the ipad ? ( student'),
#  ('directional', 'null'),
#  ('directional', 'where are the copy-machine'),
#  ('directional', 'null'),
#  ('directional', '213 ?'),
#  ('directional', 'have u scissors ?'),
#  ('directional', 'job application printing help'),
#  ('directional', 'stapler ?'),
#  ('directional', 'computer 255 ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'room 213 ?'),
#  ('directional', 'looking for san-jose mercury article from 1980s'),
#  ('directional', 'want to send bookmark promoting gabba gabba to library'),
#  ('directional',
#   'had a question about finding info about vital records/ company property ownership'),
#  ('directional', 'fax number for library of congress'),
#  ('directional', 'how to reserve computer'),
#  ('directional', 'stapler ?'),
#  ('directional', 'computer log in ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'null'),
#  ('directional', 'is it a dollar to get a print card ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'how to use computer ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'search for the mystery bookcase'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'null'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'null'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'null'),
#  ('directional', 'test monitoring service at san-jose-state-university ?'),
#  ('directional',
#   'independent author wanting to have his book available at the library'),
#  ('directional', 'internet search help'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "where 's cambrian library ?"),
#  ('directional', 'how can i tell if an article online is a peer reviewed'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'magic tree house book ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'drawing book ?'),
#  ('directional', "where 's computer class ?"),
#  ('directional', 'null'),
#  ('directional',
#   'looking for computer/problems with logging in and reserving one'),
#  ('directional', 'do you have the new business listing ?'),
#  ('directional', 'reserving a room in the library'),
#  ('directional',
#   'how did you hear about the student learning and research common ?'),
#  ('directional', 'can i checkout laptop ?'),
#  ('directional', 'null'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'do you have any volunteer oppurtnities for 12 year old ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'http : //doodle.com/hy7p8dm4ivxztupf'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'null'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'where do i pick up the hold ?'),
#  ('directional', 'where are the language cd ?'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'follow-up to research question for term paper .'),
#  ('directional', 'am i too late for 4pm craft program'),
#  ('directional', 'can i borrow an eraser'),
#  ('directional', 'where are the kit with audio cd and book'),
#  ('directional', 'null'),
#  ('directional', "where is the friend 's bookstore ?"),
#  ('directional', 'may i have some scrap paper'),
#  ('directional', 'my pin-number is not working .'),
#  ('directional', 'wanted printed u & ca tax form'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'san-jose phonebook ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'do you do the tax here ? ? ?'),
#  ('directional', 'what time is story time ?'),
#  ('directional', 'where is your teen room ?'),
#  ('directional', 'null'),
#  ('directional', 'which computer can i use the catalog on ?'),
#  ('directional', 'pin-number'),
#  ('directional', 'where is room 326 ?'),
#  ('directional', 'where is the restroom'),
#  ('directional', 'customer wanted a computer disk'),
#  ('directional', 'want to arrange a class visit'),
#  ('directional', 'mouse on compuer 34 is not working properly'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'library-card question'),
#  ('directional', 'looking for thomas book'),
#  ('directional', 'looking for berenstein bear'),
#  ('directional', 'need a floppy disc'),
#  ('directional', 'null'),
#  ('directional', 'how did you hear about the mezzanine ?'),
#  ('directional', 'needed help finding a book on 6th floor'),
#  ('directional', 'null'),
#  ('directional', 'series ?'),
#  ('directional', 'how did you hear abou the mezzanine ?'),
#  ('directional', 'null'),
#  ('directional', 'returned dvd still on record'),
#  ('directional', 'book for pre k'),
#  ('directional', 'dr sue title'),
#  ('directional', 'animorphs'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'any free parking for the library ?'),
#  ('directional',
#   'can i return book borrowed here to the berryessa branch of san-josepl'),
#  ('directional', 'what kind of program do you have for 5 year old'),
#  ('directional',
#   'can i get a new library-card to replace my old one ( worn out )'),
#  ('directional', 'can i checkout here'),
#  ('directional', 'restroom ?'),
#  ('directional', 'call security unlock door for program'),
#  ('directional', 'italian movie ?'),
#  ('directional', 'restroom ?'),
#  ('directional', 'chinese book ?'),
#  ('directional', 'chinese book ?'),
#  ('directional', 'spanish book ?'),
#  ('directional', 'where tks'),
#  ('directional', 'where is the fiction section'),
#  ('directional', 'i lost my library-card , can i get a new one ?'),
#  ('directional', 'direction to native plant in a california garden talk'),
#  ('directional', 'how many book may i check out ?'),
#  ('directional', 'can i check out my library book if i dont have my card ?'),
#  ('directional', 'wheres the restroom ?'),
#  ('directional', 'where is your teen room ?'),
#  ('directional',
#   "what time doe the gym close ? is n't this the bascom community center ?"),
#  ('directional', 'where is your craft program ? ?'),
#  ('directional', 'do you have the rainbow magic series ?'),
#  ('directional', 'where is your spanish childrens book ?'),
#  ('directional', 'can i fill out a volunteer app ?'),
#  ('directional', 'null'),
#  ('directional', 'library floor chart'),
#  ('directional', 'where are documentary'),
#  ('directional', 'null'),
#  ('directional', 'extension'),
#  ('directional', 'biography'),
#  ('directional', 'series'),
#  ('directional', 'where are travel magazine'),
#  ('directional', 'magazine'),
#  ('directional', 'null'),
#  ('directional', 'young adult book ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'customer called and wanted a book from 8th floor'),
#  ('directional', 'where are the magazine and journal ?'),
#  ('directional', 'what time you close tonight ?'),
#  ('directional', 'do i checkout childrens material out front'),
#  ('directional', 'where are the catalog computer'),
#  ('directional', 'null'),
#  ('directional', 'where are the i spy book'),
#  ('directional', 'where are the biography of famous black history figure'),
#  ('directional', 'can i leave this book to be reshelved with you'),
#  ('directional', 'null'),
#  ('directional', 'book by author of kite runner'),
#  ('directional', 'what time do you close today'),
#  ('directional', 'book on gardening and household repair'),
#  ('directional',
#   'english 1b student need info for a paper on renewable energy. i am having trouble finding in depth pro and con for solar and wind power .'),
#  ('directional', 'do you have any series book ?'),
#  ('directional', 'do you have any of these book ?'),
#  ('directional', 'do you have a certain book ?'),
#  ('directional', 'can you find me anything on agenda 21 ?'),
#  ('directional', 'patron seeking if book is in .'),
#  ('directional', 'do you have a book on mission ?'),
#  ('directional', 'seeking address'),
#  ('directional', 'null'),
#  ('directional',
#   'can you help me find critical and biographical information on f. scott fitzgerald ?'),
#  ('directional', 'question about computer .'),
#  ('directional', 'where is your nonfiction section ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'room 224'),
#  ('directional', 'looking for room 390'),
#  ('directional', 'null'),
#  ('directional', 'copy-machine'),
#  ('directional', 'how can i get a book if special collection is closed ?'),
#  ('directional', "mystery child book and where is the `` mystery door ''"),
#  ('directional', 'looking for graphic novel'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'customer called and asked if he could return an san-josepl dvd checked out from alum rock branch to king-library'),
#  ('directional', 'null'),
#  ('directional', 'which floor can i go to read without noise ?'),
#  ('directional', 'do you have these book ?'),
#  ('directional', 'null'),
#  ('directional', 'can you help me find this book ?'),
#  ('directional', 'where is your teen area ?'),
#  ('directional', 'where do i get a print card ?'),
#  ('directional', 'is the cafe only for student ?'),
#  ('directional', 'critical essay on hemingway .'),
#  ('directional', 'where is your catalog ?'),
#  ('directional', 'do you have this book ?'),
#  ('directional', 'which computer can i use to print ?'),
#  ('directional', 'do you have this book ?'),
#  ('directional', 'i need to reserve a computer'),
#  ('directional', 'looking to buy a copy card'),
#  ('directional', 'book on ancient egypt'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "what is `` book on shelving cart '' mean ?"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'customer located an eng-chi dictionary but wanted additiional dictionary on chi-eng'),
#  ('directional', 'where is this book : pn4129.15 f85'),
#  ('directional', 'looking for this book on 3rd floor : 302 gladwell'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where to find book on guitar-playing'),
#  ('directional',
#   "had to call security after staff member found 21 '' machete in the stack"),
#  ('directional', 'where is lawyer on the library'),
#  ('directional', 'can you give me my library number'),
#  ('directional', 'cvustomer looking for lost headphone'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is computer 3-42'),
#  ('directional', 'null'),
#  ('directional', 'question about job search station'),
#  ('directional', 'null'),
#  ('directional', 'where put money on tower-card'),
#  ('directional', 'how to print ?'),
#  ('directional', 'stapler'),
#  ('directional', 'problem with yahoo account .'),
#  ('directional', "hole puncher 's missing a hole !"),
#  ('directional', 'needed computer with spss software'),
#  ('directional', 'where is room 213'),
#  ('directional', 'where is room 213 ?'),
#  ('directional', 'looking for binder that includes scholarship and grant .'),
#  ('directional', '213 ?'),
#  ('directional', 'where is room 213 ?'),
#  ('directional', 'how can i find 3-12 cmp ?'),
#  ('directional', 'where is computer 2-47 ?'),
#  ('directional', 'how to print .'),
#  ('directional', 'where is room 213 ?'),
#  ('directional', 'stapler ?'),
#  ('directional', "child 's dvd"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is the learning common ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   "student in professor semerjian 's sport psychology class wanted to get oriented to database ."),
#  ('directional', 'null'),
#  ('directional', 'what is the bookmobile route ?'),
#  ('directional', 'esl material'),
#  ('directional', 'career/test book'),
#  ('directional', 'availability this afternoon'),
#  ('directional', 'looking for bill breaker'),
#  ('directional', 'white page phone book'),
#  ('directional', 'printing'),
#  ('directional',
#   'directed customer to the self-check and checkout desk in lobby'),
#  ('directional', "maintenance woman 's bathroom door handle broken"),
#  ('directional', 'looking for pop magazine .'),
#  ('directional', 'direction to st. francis cabrini church by bus'),
#  ('directional', 'pen ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where can i find the fairy tale'),
#  ('directional', 'where do i check out my book'),
#  ('directional', 'interested in volunteer experience for my son'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'phone-number .'),
#  ('directional', 'need a dictionary'),
#  ('directional', 'for card and california room'),
#  ('directional', 'where is room 224 ?'),
#  ('directional', 'null'),
#  ('directional', 'copy-machine ?'),
#  ('directional',
#   'i need to find out who the reviewer are for american institute for conservation. what are their credential ?'),
#  ('directional', 'rm 213 .'),
#  ('directional', 'null'),
#  ('directional',
#   'this booking ( computer 3-40 ) ? if i log into a computer it will give me 30 minute ?'),
#  ('directional', 'null'),
#  ('directional', 'where is reading buddy taking place ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'do you have color copier ( for the public ) ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'seeking how to get a san-josepl card'),
#  ('directional', 'classroom'),
#  ('directional', 'copier'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'room 392'),
#  ('directional', 'looking for a book in ya fiction'),
#  ('directional', 'admitting # to stanford hospital'),
#  ('directional', 'caltrain station address in palo alto'),
#  ('directional', '2012 tax table'),
#  ('directional', 'looking for news paper .'),
#  ('directional', 'can you look up my library-card number ?'),
#  ('directional',
#   'bus direction to king and then to s. almaden. wanted branch library and hours. wanted if we could provide computer assistance. etc , etc , etc ... .'),
#  ('directional', 'where is the ca room ?'),
#  ('directional', 'do you have a phone i could use ?'),
#  ('directional', 'computer question'),
#  ('directional',
#   "i am trying to get cengage brain to work so i can do some preserve-a-computertice test but the number izzie brown gave u on the syllabus is n't working. is there another number i could use ?"),
#  ('directional', 'null'),
#  ('directional', "locating a book `` who moved my cheese ''"),
#  ('directional', 'faculty wanted to put a hold on this dvd : unnatural cause'),
#  ('directional', 'patron want a copy of twilight'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'use the internet'),
#  ('directional', 'use the internet'),
#  ('directional', 'classroom 213'),
#  ('directional', 'classroom 213'),
#  ('directional', 'classroom 213'),
#  ('directional', 'temporary library-card'),
#  ('directional', 'tax return help ?'),
#  ('directional', 'donate national geographic mag ?'),
#  ('directional', 'hour for california room'),
#  ('directional', 'student interested in game study'),
#  ('directional', 'null'),
#  ('directional', 'stapler .'),
#  ('directional', 'course catalog from 1989 .'),
#  ('directional', 'room 213 .'),
#  ('directional', 'room 213'),
#  ('directional', '2-55'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how did you know about the mezz'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'california room .'),
#  ('directional', "where 's room 213 ?"),
#  ('directional', "where 's room 217"),
#  ('directional', 'where to check out chc book .'),
#  ('directional', 'can i have your discarded magazine ?'),
#  ('directional', 'null'),
#  ('directional', 'restroom'),
#  ('directional', 'location of staff member'),
#  ('directional',
#   'seeking a music book not on shelf. classmate had it yesterday and made copy. redirected him to the 3rd and 2nd floor if copy remained on floor with copier .'),
#  ('directional', 'how did you know about the mezz'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how can i find a record ?'),
#  ('directional', 'null'),
# ...
#  ('directional', 'study-room ll 02'),
#  ('directional', 'where do i find this study-room ?'),
#  ('directional', 'where is room 390 ?'),
#  ('directional', 'null'),
#  ('directional', 'how do i get a library-card ?'),
#  ('directional', 'can i fill out the library application at home ?'),
#  ('directional', 'null'),
#  ('directional', 'where do i pick up my library-card ?'),
#  ('directional', 'how can i apply for a card if im under 18 ?'),
#  ('directional', 'scratch paper'),
#  ('directional', 'where can i look up a book ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where do i sign up for a library-card ?'),
#  ('directional', 'how can i pay late fine ?'),
#  ('directional', 'where do i pick up book on hold ?'),
#  ('directional', 'looking for a math book .'),
#  ('directional', 'is this the phone-number to the county jail ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'can i use the hole puncher ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where do i pick up hold ?'),
#  ('directional', 'large print fiction book section'),
#  ('directional', 'null'),
#  ('directional', 'restroom'),
#  ('directional',
#   'san-jose-state-university student. how do i start research ?'),
#  ('directional', 'course reserve'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'pay fine'),
#  ('directional', 'where are the vietnamese dvd ?'),
#  ('directional', 'null'),
#  ('directional', 'plastic bag'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how do i print ?'),
#  ('directional', 'hold ( not at our desk )'),
#  ('directional',
#   'returned item in box on university side , will they get checked-in'),
#  ('directional', 'update limited borrower card'),
#  ('directional',
#   'need help finding the kite runner , so many entry and not sure how to use catalog. need it for a class in 10 minute !'),
#  ('directional', 'help figuring out course reserve call #'),
#  ('directional',
#   'need info on a book turned in at alamaden , should have come to king , but still listed a overdue'),
#  ('directional', 'customer asked when newspaper will arrive'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'il c/o'),
#  ('directional', 'il c/o'),
#  ('directional', 'null'),
#  ('directional',
#   "king_wifi would n't log in on patron 's laptop though seemed to authenticate. then alert said web page failed to load ."),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'asked for ref. help'),
#  ('directional', 'null'),
#  ('directional', 'where are the thomas guide ?'),
#  ('directional', 'il c/o'),
#  ('directional', 'checkout and pay fine'),
#  ('directional', 'looking for santa-clara county thomas guide'),
#  ('directional', 'null'),
#  ('directional', 'patron asked what time library closed for public'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'cafeteria ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'customer informed about flooded restroom'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where pay fine online ?'),
#  ('directional', 'can i return my willow glen book to any branch ?'),
#  ('directional', 'can i have a business card for engineering librarian ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how to use the catalog'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'renew material'),
#  ('directional', 'null'),
#  ('directional', 'can i use any computer ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how to place a hold'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where are the ya dvd'),
#  ('directional', 'renew material'),
#  ('directional', 'returned book - still show on record'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   "brenda discus about the barron 's subscription being stopped and will continue on nov 5th"),
#  ('directional', 'null'),
#  ('directional', 'where do i check out'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'check out a book not checked out by patron previously -brought back from outside of the library .'),
#  ('directional', 'cancel a booking for compuer use'),
#  ('directional', 'appt ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'are you going to have a halloween event this year ?'),
#  ('directional',
#   'call at phone - one of the staff member will be late due to trafffic'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'computer # 52 ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'asking for a staff memebers email'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'looking for a ncu 1.8 : ex1/3 number'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'wanted info in volunteering reading to child'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'looking for linear algebra journal'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is the student computer service center ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'can you help me find this government publication ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'can i check out these periodical ? ( faculty )'),
#  ('directional', 'looking for journal of homosexuality'),
#  ('directional', 'item renewal'),
#  ('directional', 'borrow a pencil'),
#  ('directional', 'where do i return book'),
#  ('directional', 'can i get a disinfectant wipe ?'),
#  ('directional', 'how do i print wireless from my own device'),
#  ('directional', 'where do i pick up my hold'),
#  ('directional', 'null'),
#  ('directional',
#   'self-checks did not give receipt , want it for book checked out'),
#  ('directional', 'esl conversation club program'),
#  ('directional', 'do you have any white-out i can use ?'),
#  ('directional',
#   'can i take a government publication anywhere in the library ?'),
#  ('directional', 'new student car'),
#  ('directional', 'new student card'),
#  ('directional', 'i want to schedule a time for a family court session .'),
#  ('directional', 'claim returned dvd'),
#  ('directional', 'where are spanish book ?'),
#  ('directional',
#   "can not find a book on 8th floor , did not know what `` folio '' means. wanted help with her research"),
#  ('directional', 'make change'),
#  ('directional', 'purchase trash bag'),
#  ('directional',
#   "i 'm looking for document by the san-jose city council that are at least 8 year old ."),
#  ('directional',
#   'name in account is spelled incorrectly. can the font be changed so it is easier to find on the hold shelf ? , usually book are misfiled .'),
#  ('directional', 'null'),
#  ('directional',
#   'patron came with replacement for university book , then wanted to pay processing fee with credit card , said someone told her she could etc , etc , did not want to pay online w/ credit card , took book back and went to find an atm'),
#  ('directional', 'null'),
#  ('directional', 'study-room'),
#  ('directional', 'null'),
#  ('directional', 'restroom ?'),
#  ('directional', 'login'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "patron ca n't open cdrom at public-computer"),
#  ('directional', 'scanner'),
#  ('directional', 'study-room'),
#  ('directional', 'transfer to loree oak'),
#  ('directional', 'san-josemn newspaper'),
#  ('directional',
#   'former student account expired , want to reserve a group study-room'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'newsweek'),
#  ('directional', 'california room location ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "today 's newspaper"),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'study-room'),
#  ('directional', 'null'),
#  ('directional', 'san-josemn microfilm'),
#  ('directional', 'null'),
#  ('directional', 'add $ to tower-card'),
#  ('directional', 'null'),
#  ('directional', 'needed sunday san-josemn newspaper'),
#  ('directional', 'null'),
#  ('directional', 'supply'),
#  ('directional', 'want to print something from her usb wand'),
#  ('directional', 'where is copy-machine ?'),
#  ('directional',
#   'had a very complex question about shipping regulation and the difference between them .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'a san-jose-state-university faculty member wanted to order a tech report through interlibrary loan'),
#  ('directional', 'null'),
#  ('directional', 'study-room'),
#  ('directional', 'looking for room 214'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'customer ha a meeting in room 225 but all the door are locked'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is room 225 ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'looking for article on advertising in america and socialist realism'),
#  ('directional', 'how much doe it cost to copy a page ?'),
#  ('directional', 'null'),
#  ('directional', "why doe n't my tower-card work on self check ?"),
#  ('directional', 'can i copy article ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how to print'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where can i borrow a laptop ?'),
#  ('directional', 'null'),
#  ('directional', 'where are the restroom ?'),
#  ('directional', 'null'),
#  ('directional',
#   'can i get the phone-number and address to the la vega police department ? can i also get the hiring department office ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', "where are the child 's book ?"),
#  ('directional', 'do you have a pen i could borrow ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'fiction book'),
#  ('directional', 'do you have the journal literature and psychology ?'),
#  ('directional', 'phone reference referral'),
#  ('directional', 'where is computer 2-51'),
#  ('directional', 'null'),
#  ('directional', 'which computer have window 7-32 bit that i can use ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'patron started seizing'),
#  ('directional', 'null'),
#  ('directional', 'where are the copier ?'),
#  ('directional', 'null'),
#  ('directional', 'where can i get a laptop ?'),
#  ('directional', 'where is the chiro room ?'),
#  ('directional', 'where is room ll02 ?'),
#  ('directional', 'do you have the time ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'restroom'),
#  ('directional', 'null'),
#  ('directional', 'where is the juvenile section on this floor ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is 900 book'),
#  ('directional', 'null'),
#  ('directional',
#   'anyone turn in a beanie ? black with red yellow green stripe ?'),
#  ('directional', 'newspaper'),
#  ('directional',
#   'customer asked to call library secusrity for a person laying on the floor'),
#  ('directional', 'someone left these ( sunglass ) in that corner'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'where is the spss program'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'study-room'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional',
#   'hi i need the counseling department for gavilan college. great ! now i need the applied science department for gavilan. i wa told this will be in the main campus .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how do i get a course reserve ?'),
#  ('directional', 'null'),
#  ('directional', 'copy-machine'),
#  ('directional', 'course reserve'),
#  ('directional', 'null'),
#  ('directional', 'help with printing from her laptop'),
#  ('directional', 'null'),
#  ('directional', 'where do i print my paper at ?'),
#  ('directional', 'where can i pay fine with credit card ?'),
#  ('directional', 'null'),
#  ('directional', 'where do i return book ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'comment form'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'how do i long into a computer ?'),
#  ('directional', 'null'),
#  ('directional', 'validation'),
#  ('directional', 'link+'),
#  ('directional', 'null'),
#  ('directional', 'where are the jr picture book'),
#  ('directional', 'wanted to speak to nancy buckle'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'water bottle'),
#  ('directional', 'null'),
#  ('directional', 'validation x2'),
#  ('directional', "example of various child 's televison program to check out"),
#  ('directional', 'link+'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'link+'),
#  ('directional', 'il'),
#  ('directional', 'null'),
#  ('directional', 'calif. room hour'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'can you make colored copy ?'),
#  ('directional', 'null'),
#  ('directional', 'where can i buy a print card ?'),
#  ('directional', 'null'),
#  ('directional', 'unable to log on to public-computer .'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'hour'),
#  ('directional', 'book without barcodes on back'),
#  ('directional', 'do you have any plastic bag ?'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null'),
#  ('directional', 'null')]

# %% [markdown]
# ##  What percentage of directional questions concern meeting rooms, classrooms,
#
# bathrooms, study rooms, etc. Other locations?

# %%
q = backend.QueryBuilder()
q.set_columns(['Question', 'Answer'])
q.set_condition('Question NOT', 'null')
q.set_condition('AND Question', 'meeting room')
q.set_condition('OR Question', 'classroom')
q.set_condition('OR Question', 'bathrooms')
q.set_condition('OR Question', 'study room')
q.limit = 0
q.execute(con)

mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results 
mfw = analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words 
pie_chart(mfw)
# Out:
# Columns:  ['Question', 'Answer']
# Conditions:  [('Question NOT', 'null'), ('AND Question', 'meeting room'), ('OR Question', 'classroom'), ('OR Question', 'bathrooms'), ('OR Question', 'study room')]
# Limit: 0
# Columns:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-942022bd34ad> in <module>()
#      10
#      11 mytext = analyzer.get_text( q.execute(con) )  # read the text-body from results
# ---> 12 mfw = analyzer.get_most_frequest_words(mytext, 25)  # Print most frequent words
#      13 pie_chart(mfw)
#
# AttributeError: DataAnalyzer instance has no attribute 'get_most_frequest_words'
#  ['Question', 'Answer']
# Conditions:  [('Question NOT', 'null'), ('AND Question', 'meeting room'), ('OR Question', 'classroom'), ('OR Question', 'bathrooms'), ('OR Question', 'study room')]
# Limit: 0
